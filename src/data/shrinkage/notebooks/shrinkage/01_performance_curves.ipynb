# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib
import os
import sys

import matplotlib.pyplot as plt

sys.path.append('../..')

plt.rcParams['figure.dpi'] = 250
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# change working directory to project root
if os.getcwd().split('/')[-1] == 'notebooks':
    os.chdir('../..')
from imodels_experiments.config.shrinkage.datasets import DATASETS_CLASSIFICATION, DATASETS_REGRESSION
from imodels_experiments.util import DATASET_PATH



import imodels_experiments.viz as viz
from viz import *
from os.path import join as oj
import matplotlib.pyplot as plt

RESULTS_PATH = oj(os.path.dirname(DATASET_PATH), 'results')

print('num_datasets', len(DATASETS_CLASSIFICATION), len(DATASETS_REGRESSION))

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using matplotlib backend: macosx
# num_datasets 11 9

# %%
# run comparison aggregations
# !python3 "/Users/pantia-marinaalchirch/PycharmProjects/imodels-experiments/imodels_experiments/02_aggregate_results.py"
# Out:
# /Users/pantia-marinaalchirch/PycharmProjects/imodels-experiments/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/pantia-marinaalchirch/PycharmProjects/imodels-experiments/imodels_experiments/02_aggregate_results.py:53: UserWarning: bad complexity range
#   warnings.warn(f'bad complexity range')
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 59.45it/s]
# successfully processed 1 / 1 individual seeds
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 49.30it/s]
# successfully processed 1 / 1 averaged seeds

# %% [markdown]
# # overarching plots

# %%
viz.plot_comparisons(metric='r2', datasets=DATASETS_REGRESSION,  # len(DATASETS_REGRESSION)
                     models_to_include=['ShrunkCART', 'CART_(MSE)',
                                        'Shrunk_Random_Forest', 'Random_Forest',
                                        'Shrunk_Gradient_Boosting', 'Gradient_Boosting'],
                     save_name='shrinkage-regression-reg')

# viz.plot_comparisons(metric='r2', datasets=DATASETS_REGRESSION,  # len(DATASETS_REGRESSION)
#                      models_to_include=['ShrunkCART', 'CART_(MSE)',
#                                         'Shrunk_Random_Forest', 'Random_Forest',
#                                         'Shrunk_Gradient_Boosting', 'Gradient_Boosting'],
#                      save_name='shrinkage-regression-reg', data_type='reg_data')
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 viz.plot_comparisons(metric='r2', datasets=DATASETS_REGRESSION,  # len(DATASETS_REGRESSION)
#       2                      models_to_include=['ShrunkCART', 'CART_(MSE)',
#       3                                         'Shrunk_Random_Forest', 'Random_Forest',
#       4                                         'Shrunk_Gradient_Boosting', 'Gradient_Boosting'],
#       5                      save_name='shrinkage-regression-reg')
#       7 # viz.plot_comparisons(metric='r2', datasets=DATASETS_REGRESSION,  # len(DATASETS_REGRESSION)
#       8 #                      models_to_include=['ShrunkCART', 'CART_(MSE)',
#       9 #                                         'Shrunk_Random_Forest', 'Random_Forest',
#      10 #                                         'Shrunk_Gradient_Boosting', 'Gradient_Boosting'],
#      11 #                      save_name='shrinkage-regression-reg', data_type='reg_data')
#
# File ~/PycharmProjects/imodels-experiments/imodels_experiments/viz.py:102, in plot_comparisons(metric, datasets, models_to_include, models_to_include_dashed, config_name, color_legend, seed, eps_legend_sep, save_name, show_train, xlim, C)
#     100 if seed is None:
#     101     pkl_file = oj('results', config_name, dset_name, 'train-test/results_aggregated.pkl')
# --> 102     df = pkl.load(open(pkl_file, 'rb'))['df_mean']
#     103     # print('ks', df.keys())
#     104 else:
#     105     pkl_file = oj('results', config_name, dset_name, 'train-test/seed0/results_aggregated.pkl')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/figs/friedman1/train-test/results_aggregated.pkl'

# %%
viz.plot_comparisons(metric='rocauc', datasets=DATASETS_CLASSIFICATION,
                     models_to_include=['CART', 'Random_Forest', 'Gradient_Boosting'],
                     save_name='shrinkage-classification')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 viz.plot_comparisons(metric='rocauc', datasets=DATASETS_CLASSIFICATION,
#       2                      models_to_include=['CART', 'Random_Forest', 'Gradient_Boosting'],
#       3                      save_name='shrinkage-classification')
#
# File ~/PycharmProjects/imodels-experiments/imodels_experiments/viz.py:102, in plot_comparisons(metric, datasets, models_to_include, models_to_include_dashed, config_name, color_legend, seed, eps_legend_sep, save_name, show_train, xlim, C)
#     100 if seed is None:
#     101     pkl_file = oj('results', config_name, dset_name, 'train-test/results_aggregated.pkl')
# --> 102     df = pkl.load(open(pkl_file, 'rb'))['df_mean']
#     103     # print('ks', df.keys())
#     104 else:
#     105     pkl_file = oj('results', config_name, dset_name, 'train-test/seed0/results_aggregated.pkl')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/figs/sonar/train-test/results_aggregated.pkl'

# %%
# viz.plot_comparisons(metric='r2', datasets=DATASETS_REGRESSION,
#                 models_to_include=['ShrunkCART', 'CART_(MSE)',
#                                    'Shrunk_Random_Forest', 'Random_Forest',
#                                    'Shrunk_Gradient_Boosting', 'Gradient_Boosting'],
#                      save_name='shrinkage-regression-low', data_type='low_data')

# %% [markdown]
# #Marina : Classification datasets
