# %%
from Code.incremental_kde import california_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 0.1, 1, 10, 15, 20],
    'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       # 'lambda_list' : [0, 50, 100],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

california_experiment(model_name='ht', no_lambda=False, parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# Data shape after dropping illogical examples:  (20635, 9)
# Size of X: 20635
# Size of y: 20635
# initializing an ht
# model name is ht
# models to tune : 1081
# tuning_window_size: 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 3.765152089570725
# lambda: 0.1, mse : 3.765152089570725
# lambda: 1, mse : 3.765152089570725
# lambda: 10, mse : 3.765152089570725
# lambda: 15, mse : 3.765152089570725
# lambda: 25, mse : 3.765152089570725
#
# Finished Tuning on lambda
# best model mse : 3.765152089570725
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.34762394780821737
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       2 #Second experiment with KDE+HS
#       3 parameters = {
#       4        #'lambda_list' : [0, 0.1, 1, 10, 15, 20],
#       5     'lambda_list' : [0, 0.1, 1, 10, 15, 25],
#    (...)      9        'window_size_list': [50, 100, 200]
#      10     }
# ---> 12 california_experiment(model_name='ht', no_lambda=False, parameters=parameters)
#
# File ~/PycharmProjects/ht_library_my_version/Code/incremental_kde.py:610, in california_experiment(model_name, no_lambda, n_rows, metric, parameters)
#     607 scaler = MinMaxScaler()
#     608 X_scaled = scaler.fit_transform(X)
# --> 610 ht_preds, ht_hs_preds, kde_preds, y_true = tune_and_train(
#     611     parameters=parameters,
#     612     X=X_scaled,
#     613     y=y,
#     614     tune_metric_selection=metric,
#     615     tuning_times=4,
#     616     no_lambda=no_lambda,
#     617     model_name=model_name
#     618 )
#     620 np.savetxt('/Users/pantia-marinaalchirch/PycharmProjects/ht_library_my_version/results/'+model_name+'/california/ht_preds.txt', ht_preds)
#     621 np.savetxt('/Users/pantia-marinaalchirch/PycharmProjects/ht_library_my_version/results/'+model_name+'/california/ht_hs_preds.txt', ht_hs_preds)
#
# File ~/PycharmProjects/ht_library_my_version/Code/incremental_kde.py:411, in tune_and_train(parameters, X, y, model_name, tune_metric_selection, tuning_times, no_lambda)
#     407     X_tune_batch = X[start_idx:end_idx].reshape(-1, X.shape[1])
#     409 # print(f'X_tune_batch size : {X_tune_batch.shape}')
# --> 411 model.predict_then_fit(X_tune_batch, y[start_idx:end_idx])
#     412 # print(f' j is : {j}')
#     413 # print(f'start_idx: {start_idx}, end_idx: {end_idx}')
#     414 # print(f'model.predictions size : {len(model.predictions)}')
#     415 if flag:
#
# File ~/PycharmProjects/ht_library_my_version/Code/model.py:135, in IncrKDEModel.predict_then_fit(self, X, y)
#     132     label = y.iloc[label_idx] if isinstance(y, pd.Series) else y[label_idx]
#     134     for label_key in self.weights.keys():
# --> 135         self.weights[label_key] = self.weight_update(instances_seen, self.weights[label_key], label_key,
#     136                                            label, self.parameters['kernel'], self.parameters['h'])
#     138     instances_seen += 1  # Increment counter
#     140 normalized_incremental_weights = self.weights.copy()
#
# File ~/PycharmProjects/ht_library_my_version/Code/model.py:216, in IncrKDEModel.weight_update(self, num_instances, prev_weight, z_query, z, kernel, h)
#     215 def weight_update(self, num_instances, prev_weight, z_query, z, kernel, h=1.0):
# --> 216     kernel_value = kernel.get_kernel_value((z_query - z) / h)
#     217     new_weight = prev_weight + (1 / (num_instances + 1)) * ((kernel_value / h) - prev_weight)
#     218     return new_weight
#
# File ~/PycharmProjects/ht_library_my_version/Code/kernels.py:9, in CustomGaussianKernel.get_kernel_value(self, z)
#       8 def get_kernel_value(self, z):
# ----> 9     kernel_value = (1 / (np.sqrt(2 * np.pi) * self.sigma)) * np.exp(- (((z ** 2) / (2 * (self.sigma ** 2)))))
#      10     return kernel_value
#
# KeyboardInterrupt:

# %%
from Code.incremental_kde import california_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

california_experiment(model_name='ht', no_lambda=True, parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# Data shape after dropping illogical examples:  (20635, 9)
# Size of X: 20635
# Size of y: 20635
# initializing an ht
# no lambda tuning in KDE
# model name is ht
# models to tune : 181
# tuning_window_size: 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 3.765152089570725
# lambda: 0.1, mse : 3.765152089570725
# lambda: 1, mse : 3.765152089570725
# lambda: 10, mse : 3.765152089570725
# lambda: 15, mse : 3.765152089570725
# lambda: 25, mse : 3.765152089570725
#
# Finished Tuning on lambda
# best model mse : 3.765152089570725
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.34762394780821737
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.28721365245287195
# Finished Tuning [1/4] in 1254.55 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x142671cd0>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [2/4] at example 5158...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 1.595753248436627
# lambda: 0.1, mse : 1.5948424005790778
# lambda: 1, mse : 1.586687927505422
# lambda: 10, mse : 1.509234210420839
# lambda: 15, mse : 1.469219185794158
# lambda: 25, mse : 1.3950303085824567
#
# Finished Tuning on lambda
# best model mse : 1.3950303085824567
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.45222676697529335
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.32018709234932075
# Finished Tuning [2/4] in 1301.66 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x30b1a5c90>, 'kde_type': 'binned', 'range_of_bin': 0.1}
#
# before i+=tuning_window_size, i is : 5158
# after i+=tuning_window_size, i is : 7737
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [3/4] at example 10317...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.45043156555007324
# lambda: 0.1, mse : 0.45030409418955625
# lambda: 1, mse : 0.44916790935354506
# lambda: 10, mse : 0.4388429130753198
# lambda: 15, mse : 0.43385876751969593
# lambda: 25, mse : 0.4253112584513242
#
# Finished Tuning on lambda
# best model mse : 0.4253112584513242
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.41928562811198944
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.3904184686971898
# Finished Tuning [3/4] in 1314.60 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x33317be90>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 10317
# after i+=tuning_window_size, i is : 12896
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [4/4] at example 15476...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.3200910098346347
# lambda: 0.1, mse : 0.3200968230833092
# lambda: 1, mse : 0.3201556671783061
# lambda: 10, mse : 0.32134782377951915
# lambda: 15, mse : 0.3224390696525848
# lambda: 25, mse : 0.32540459345240136
#
# Finished Tuning on lambda
# best model mse : 0.3200910098346347
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.7126315936314598
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.47965933331844823
# Finished Tuning [4/4] in 1357.93 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x364877dd0>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 15476
# after i+=tuning_window_size, i is : 18055
# Size of ht predictions: 10319
# Size of kde predictions: 10319
# Size of actual labels: 10319
#
# Final Mean Squared Errors:
# ht MSE:      0.4542
# ht+HS MSE:   0.4635
# ht+KDE MSE:   0.4221

# %%
from Code.incremental_kde import electric_power_comsumption_experiment

parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

electric_power_comsumption_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/household_power_consumption.txt", model_name='ht', n_rows=100000, no_lambda=False, parameters=parameters)
# Out:
# (99992, 8) (99992,)
# initializing an ht
# model name is ht
# models to tune : 1081
# tuning_window_size: 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 5.788644349398552
# lambda: 0.1, mse : 5.788644349398552
# lambda: 1, mse : 5.788644349398552
# lambda: 10, mse : 5.788644349398552
# lambda: 15, mse : 5.788644349398552
# lambda: 25, mse : 5.788644349398552
#
# Finished Tuning on lambda
# best model mse : 5.788644349398552
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.1254803536802148
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.041201981819254566
# Finished Tuning [1/4] in 12459.37 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3e7945fd0>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [2/4] at example 24998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.05429027144308527
# lambda: 0.1, mse : 0.054281029153409315
# lambda: 1, mse : 0.05423136987288795
# lambda: 10, mse : 0.05674867546655153
# lambda: 15, mse : 0.06019493015786582
# lambda: 25, mse : 0.0705500492747548
#
# Finished Tuning on lambda
# best model mse : 0.05423136987288795
# Best lambda after tuning: 1
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.019226667838656356
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.011527365002253024
# Finished Tuning [2/4] in 11545.87 seconds.
#
# Best parameters after tuning: {'lambda_selected': 10, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x4504bea90>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 24998
# after i+=tuning_window_size, i is : 27998
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [3/4] at example 49996...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.041813319742853426
# lambda: 0.1, mse : 0.04181386978482255
# lambda: 1, mse : 0.04185141008227234
# lambda: 10, mse : 0.04515568673040701
# lambda: 15, mse : 0.048979952604262994
# lambda: 25, mse : 0.05998650387439652
#
# Finished Tuning on lambda
# best model mse : 0.041813319742853426
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.08733566818495693
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.05937155613615648
# Finished Tuning [3/4] in 12472.45 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x5ab603350>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 49996
# after i+=tuning_window_size, i is : 52996
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [4/4] at example 74994...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.040634604320817745
# lambda: 0.1, mse : 0.04063699897918399
# lambda: 1, mse : 0.0406908120997006
# lambda: 10, mse : 0.044127752295944955
# lambda: 15, mse : 0.048004742942031914
# lambda: 25, mse : 0.05907961962535943
#
# Finished Tuning on lambda
# best model mse : 0.040634604320817745
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.02717885220227345
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.015851506460396035
# Finished Tuning [4/4] in 11527.50 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3ee44be10>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 74994
# after i+=tuning_window_size, i is : 77994
# Size of ht predictions: 87992
# Size of kde predictions: 87992
# Size of actual labels: 87992
#
# Final Mean Squared Errors:
# ht MSE:      0.0484
# ht+HS MSE:   0.0545
# ht+KDE MSE:     0.0270

# %%
from Code.incremental_kde import electric_power_comsumption_experiment

parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

electric_power_comsumption_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/household_power_consumption.txt", model_name='ht', n_rows=100000, no_lambda=True, parameters=parameters)
# Out:
# (99992, 8) (99992,)
# initializing an ht
# no lambda tuning in KDE
# model name is ht
# models to tune : 181
# tuning_window_size: 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 5.788644349398552
# lambda: 0.1, mse : 5.788644349398552
# lambda: 1, mse : 5.788644349398552
# lambda: 10, mse : 5.788644349398552
# lambda: 15, mse : 5.788644349398552
# lambda: 25, mse : 5.788644349398552
#
# Finished Tuning on lambda
# best model mse : 5.788644349398552
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.1254803536802148
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.04120592977060662
# Finished Tuning [1/4] in 2074.11 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x110946110>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [2/4] at example 24998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.05429027144308527
# lambda: 0.1, mse : 0.054281029153409315
# lambda: 1, mse : 0.05423136987288795
# lambda: 10, mse : 0.05674867546655153
# lambda: 15, mse : 0.06019493015786582
# lambda: 25, mse : 0.0705500492747548
#
# Finished Tuning on lambda
# best model mse : 0.05423136987288795
# Best lambda after tuning: 1
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.019226667838656356
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.011961205994586185
# Finished Tuning [2/4] in 1916.58 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x113c0d0d0>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 24998
# after i+=tuning_window_size, i is : 27998
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [3/4] at example 49996...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.041813319742853426
# lambda: 0.1, mse : 0.04181386978482255
# lambda: 1, mse : 0.04185141008227234
# lambda: 10, mse : 0.04515568673040701
# lambda: 15, mse : 0.048979952604262994
# lambda: 25, mse : 0.05998650387439652
#
# Finished Tuning on lambda
# best model mse : 0.041813319742853426
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.08733566818495693
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.05937155613615648
# Finished Tuning [3/4] in 2058.53 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3236f2110>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 49996
# after i+=tuning_window_size, i is : 52996
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [4/4] at example 74994...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.040634604320817745
# lambda: 0.1, mse : 0.04063699897918399
# lambda: 1, mse : 0.0406908120997006
# lambda: 10, mse : 0.044127752295944955
# lambda: 15, mse : 0.048004742942031914
# lambda: 25, mse : 0.05907961962535943
#
# Finished Tuning on lambda
# best model mse : 0.040634604320817745
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.02717885220227345
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.0159719869685927
# Finished Tuning [4/4] in 1880.55 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x113bd4650>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 74994
# after i+=tuning_window_size, i is : 77994
# Size of ht predictions: 87992
# Size of kde predictions: 87992
# Size of actual labels: 87992
#
# Final Mean Squared Errors:
# ht MSE:      0.0484
# ht+HS MSE:   0.0545
# ht+KDE MSE:     0.0269

# %%
from Code.incremental_kde import NYTaxi_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

NYTaxi_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/nyc_taxi_kaggle/train.csv", model_name='ht', n_rows=20000, no_lambda=False, parameters=parameters)
# Out:
# Processing dataset NYC TAXI
# samples : 19997, number of features : 10
# y shape : (19997,)
# initializing an ht
# model name is ht
# models to tune : 1081
# tuning_window_size: 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 42.379482888027894
# lambda: 0.1, mse : 42.379482888027894
# lambda: 1, mse : 42.379482888027894
# lambda: 10, mse : 42.379482888027894
# lambda: 15, mse : 42.379482888027894
# lambda: 25, mse : 42.379482888027894
#
# Finished Tuning on lambda
# best model mse : 42.379482888027894
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.3673294840003195
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.27422247601797606
# Finished Tuning [1/4] in 6712.50 seconds.
#
# Best parameters after tuning: {'lambda_selected': 25, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x4529287d0>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [2/4] at example 4999...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.34042299490631106
# lambda: 0.1, mse : 0.34042299490631106
# lambda: 1, mse : 0.34042299490631106
# lambda: 10, mse : 0.34042299490631106
# lambda: 15, mse : 0.34042299490631106
# lambda: 25, mse : 0.34042299490631106
#
# Finished Tuning on lambda
# best model mse : 0.34042299490631106
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2829650897770159
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.23107953423994532
# Finished Tuning [2/4] in 6905.65 seconds.
#
# Best parameters after tuning: {'lambda_selected': 15, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x5416e3610>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 7498
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [3/4] at example 9998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.2366621446426694
# lambda: 0.1, mse : 0.23666335935799027
# lambda: 1, mse : 0.2366743230762992
# lambda: 10, mse : 0.23678703029297363
# lambda: 15, mse : 0.2368520263584727
# lambda: 25, mse : 0.23698701533969577
#
# Finished Tuning on lambda
# best model mse : 0.2366621446426694
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2172457667890351
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.2172457667890351
# Finished Tuning [3/4] in 7184.69 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 9998
# after i+=tuning_window_size, i is : 12497
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [4/4] at example 14997...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.2257574915246255
# lambda: 0.1, mse : 0.22575778971632338
# lambda: 1, mse : 0.22576052601899207
# lambda: 10, mse : 0.22579294852345597
# lambda: 15, mse : 0.22581477668149136
# lambda: 25, mse : 0.22586611724368424
#
# Finished Tuning on lambda
# best model mse : 0.2257574915246255
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.20869610896140509
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.20869610896140509
# Finished Tuning [4/4] in 8221.26 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 14997
# after i+=tuning_window_size, i is : 17496
# Size of ht predictions: 10001
# Size of kde predictions: 10001
# Size of actual labels: 10001
#
# Final Mean Squared Errors:
# ht MSE:      0.2693
# ht+HS MSE:   0.2693
# ht+KDE MSE:     0.2426

# %%
from Code.incremental_kde import NYTaxi_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

NYTaxi_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/nyc_taxi_kaggle/train.csv", model_name='ht', n_rows=20000, no_lambda=True, parameters=parameters)
# Out:
# Processing dataset NYC TAXI
# samples : 19997, number of features : 10
# y shape : (19997,)
# initializing an ht
# no lambda tuning in KDE
# model name is ht
# models to tune : 181
# tuning_window_size: 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 42.379482888027894
# lambda: 0.1, mse : 42.379482888027894
# lambda: 1, mse : 42.379482888027894
# lambda: 10, mse : 42.379482888027894
# lambda: 15, mse : 42.379482888027894
# lambda: 25, mse : 42.379482888027894
#
# Finished Tuning on lambda
# best model mse : 42.379482888027894
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.3673294840003195
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.27483811060105484
# Finished Tuning [1/4] in 1111.04 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x8aa9e7150>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [2/4] at example 4999...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.34042299490631106
# lambda: 0.1, mse : 0.34042299490631106
# lambda: 1, mse : 0.34042299490631106
# lambda: 10, mse : 0.34042299490631106
# lambda: 15, mse : 0.34042299490631106
# lambda: 25, mse : 0.34042299490631106
#
# Finished Tuning on lambda
# best model mse : 0.34042299490631106
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2829650897770159
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.23119492788895413
# Finished Tuning [2/4] in 1125.89 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x1293ff850>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 7498
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [3/4] at example 9998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.2366621446426694
# lambda: 0.1, mse : 0.23666335935799027
# lambda: 1, mse : 0.2366743230762992
# lambda: 10, mse : 0.23678703029297363
# lambda: 15, mse : 0.2368520263584727
# lambda: 25, mse : 0.23698701533969577
#
# Finished Tuning on lambda
# best model mse : 0.2366621446426694
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2172457667890351
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.2172457667890351
# Finished Tuning [3/4] in 1139.64 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 9998
# after i+=tuning_window_size, i is : 12497
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [4/4] at example 14997...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.2257574915246255
# lambda: 0.1, mse : 0.22575778971632338
# lambda: 1, mse : 0.22576052601899207
# lambda: 10, mse : 0.22579294852345597
# lambda: 15, mse : 0.22581477668149136
# lambda: 25, mse : 0.22586611724368424
#
# Finished Tuning on lambda
# best model mse : 0.2257574915246255
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.20869610896140509
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.20869610896140509
# Finished Tuning [4/4] in 1156.65 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 14997
# after i+=tuning_window_size, i is : 17496
# Size of ht predictions: 10001
# Size of kde predictions: 10001
# Size of actual labels: 10001
#
# Final Mean Squared Errors:
# ht MSE:      0.2693
# ht+HS MSE:   0.2693
# ht+KDE MSE:     0.2431

# %%
from Code.incremental_kde import california_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

california_experiment(model_name='hat', no_lambda=False, parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# Data shape after dropping illogical examples:  (20635, 9)
# Size of X: 20635
# Size of y: 20635
# initializing a hat
# model name is hat
# models to tune : 1081
# tuning_window_size: 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 3.765152089570725
# lambda: 0.1, mse : 3.765152089570725
# lambda: 1, mse : 3.765152089570725
# lambda: 10, mse : 3.765152089570725
# lambda: 15, mse : 3.765152089570725
# lambda: 25, mse : 3.765152089570725
#
# Finished Tuning on lambda
# best model mse : 3.765152089570725
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.3287726969782606
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.2735863160596516
# Finished Tuning [1/4] in 7758.02 seconds.
#
# Best parameters after tuning: {'lambda_selected': 25, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x36fff6d50>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [2/4] at example 5158...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 1.0216815648005135
# lambda: 0.1, mse : 1.0215604569803158
# lambda: 1, mse : 1.0204745520865512
# lambda: 10, mse : 1.0100072921729144
# lambda: 15, mse : 1.0044879088434093
# lambda: 25, mse : 0.9940439122989483
#
# Finished Tuning on lambda
# best model mse : 0.9940439122989483
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.3920401968232385
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.2682903185649212
# Finished Tuning [2/4] in 7996.14 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3927ebe90>, 'kde_type': 'binned', 'range_of_bin': 0.1}
#
# before i+=tuning_window_size, i is : 5158
# after i+=tuning_window_size, i is : 7737
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [3/4] at example 10317...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.4455586928341585
# lambda: 0.1, mse : 0.44557760210981784
# lambda: 1, mse : 0.44574799737220594
# lambda: 10, mse : 0.4474723378724123
# lambda: 15, mse : 0.4484456614458548
# lambda: 25, mse : 0.45042302565729825
#
# Finished Tuning on lambda
# best model mse : 0.4455586928341585
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.4958655845903209
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.3353345928851689
# Finished Tuning [3/4] in 7922.42 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x30211de10>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 10317
# after i+=tuning_window_size, i is : 12896
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [4/4] at example 15476...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 1.1899046607109751
# lambda: 0.1, mse : 1.1896679082656083
# lambda: 1, mse : 1.1875447188904171
# lambda: 10, mse : 1.1670425956305472
# lambda: 15, mse : 1.1562023047109475
# lambda: 25, mse : 1.1356234904727143
#
# Finished Tuning on lambda
# best model mse : 1.1356234904727143
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.7093369064423226
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.3906373701426778
# Finished Tuning [4/4] in 8011.57 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x44d562d10>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 15476
# after i+=tuning_window_size, i is : 18055
# Size of ht predictions: 10319
# Size of kde predictions: 10319
# Size of actual labels: 10319
#
# Final Mean Squared Errors:
# hat MSE:      0.4537
# hat+HS MSE:   0.4593
# hat+KDE MSE:   0.4644

# %%
from Code.incremental_kde import california_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

california_experiment(model_name='hat', no_lambda=True, parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# Data shape after dropping illogical examples:  (20635, 9)
# Size of X: 20635
# Size of y: 20635
# initializing a hat
# no lambda tuning in KDE
# model name is hat
# models to tune : 181
# tuning_window_size: 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 3.765152089570725
# lambda: 0.1, mse : 3.765152089570725
# lambda: 1, mse : 3.765152089570725
# lambda: 10, mse : 3.765152089570725
# lambda: 15, mse : 3.765152089570725
# lambda: 25, mse : 3.765152089570725
#
# Finished Tuning on lambda
# best model mse : 3.765152089570725
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.3287726969782606
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.27640182734777624
# Finished Tuning [1/4] in 1290.95 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x308997910>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2579
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [2/4] at example 5158...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 1.0216815648005135
# lambda: 0.1, mse : 1.0215604569803158
# lambda: 1, mse : 1.0204745520865512
# lambda: 10, mse : 1.0100072921729144
# lambda: 15, mse : 1.0044879088434093
# lambda: 25, mse : 0.9940439122989483
#
# Finished Tuning on lambda
# best model mse : 0.9940439122989483
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.3920401968232385
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.2682903185649212
# Finished Tuning [2/4] in 1331.78 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3dafc8a50>, 'kde_type': 'binned', 'range_of_bin': 0.1}
#
# before i+=tuning_window_size, i is : 5158
# after i+=tuning_window_size, i is : 7737
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [3/4] at example 10317...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.4455586928341585
# lambda: 0.1, mse : 0.44557760210981784
# lambda: 1, mse : 0.44574799737220594
# lambda: 10, mse : 0.4474723378724123
# lambda: 15, mse : 0.4484456614458548
# lambda: 25, mse : 0.45042302565729825
#
# Finished Tuning on lambda
# best model mse : 0.4455586928341585
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.4958655845903209
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.3353733746016419
# Finished Tuning [3/4] in 1320.44 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3f8858e90>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 10317
# after i+=tuning_window_size, i is : 12896
# tuning_start_indices: [0, 5158, 10317, 15476]
# Tuning [4/4] at example 15476...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 1.1899046607109751
# lambda: 0.1, mse : 1.1896679082656083
# lambda: 1, mse : 1.1875447188904171
# lambda: 10, mse : 1.1670425956305472
# lambda: 15, mse : 1.1562023047109475
# lambda: 25, mse : 1.1356234904727143
#
# Finished Tuning on lambda
# best model mse : 1.1356234904727143
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2579
# len(model.predictions) : 2579
# fallback model mse : 0.7093369064423226
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.3906373701426778
# Finished Tuning [4/4] in 1332.24 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x43dd32510>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 15476
# after i+=tuning_window_size, i is : 18055
# Size of ht predictions: 10319
# Size of kde predictions: 10319
# Size of actual labels: 10319
#
# Final Mean Squared Errors:
# hat MSE:      0.4537
# hat+HS MSE:   0.4593
# hat+KDE MSE:   0.4632

# %%
from Code.incremental_kde import electric_power_comsumption_experiment

parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

electric_power_comsumption_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/household_power_consumption.txt", model_name='hat', n_rows=100000, no_lambda=False, parameters=parameters)
# Out:
# (99992, 8) (99992,)
# initializing a hat
# model name is hat
# models to tune : 1081
# tuning_window_size: 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 5.788644349398552
# lambda: 0.1, mse : 5.788644349398552
# lambda: 1, mse : 5.788644349398552
# lambda: 10, mse : 5.788644349398552
# lambda: 15, mse : 5.788644349398552
# lambda: 25, mse : 5.788644349398552
#
# Finished Tuning on lambda
# best model mse : 5.788644349398552
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.1254803536802148
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.041520147059587106
# Finished Tuning [1/4] in 17074.21 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x17fbf8d10>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [2/4] at example 24998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 1.109536066636207
# lambda: 0.1, mse : 1.1094817822044882
# lambda: 1, mse : 1.109007669461376
# lambda: 10, mse : 1.105578314440054
# lambda: 15, mse : 1.1045785175986966
# lambda: 25, mse : 1.104153665961793
#
# Finished Tuning on lambda
# best model mse : 1.104153665961793
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.0881563918609038
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.01579419897075074
# Finished Tuning [2/4] in 12094.82 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x30ba0f790>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 24998
# after i+=tuning_window_size, i is : 27998
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [3/4] at example 49996...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.21802159256822143
# lambda: 0.1, mse : 0.2180931984763863
# lambda: 1, mse : 0.21874208404191173
# lambda: 10, mse : 0.22564500763237016
# lambda: 15, mse : 0.2297779376039927
# lambda: 25, mse : 0.23859654450200757
#
# Finished Tuning on lambda
# best model mse : 0.21802159256822143
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.19922740791561935
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.06507550035482408
# Finished Tuning [3/4] in 16718.55 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 50, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3c8ebd690>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 49996
# after i+=tuning_window_size, i is : 52996
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [4/4] at example 74994...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.728725104999135
# lambda: 0.1, mse : 0.7290199226999493
# lambda: 1, mse : 0.7316776606999427
# lambda: 10, mse : 0.7586420286437952
# lambda: 15, mse : 0.7738759100613791
# lambda: 25, mse : 0.8047344936001488
#
# Finished Tuning on lambda
# best model mse : 0.728725104999135
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.17542148761068563
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.02285981011016287
# Finished Tuning [4/4] in 11659.69 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3c64e7350>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 74994
# after i+=tuning_window_size, i is : 77994
# Size of ht predictions: 87992
# Size of kde predictions: 87992
# Size of actual labels: 87992
#
# Final Mean Squared Errors:
# hat MSE:      0.1475
# hat+HS MSE:   0.1612
# hat+KDE MSE:     0.0477

# %%
from Code.incremental_kde import electric_power_comsumption_experiment

parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

electric_power_comsumption_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/household_power_consumption.txt", model_name='hat', n_rows=100000, no_lambda=True, parameters=parameters)
# Out:
# (99992, 8) (99992,)
# initializing a hat
# no lambda tuning in KDE
# model name is hat
# models to tune : 181
# tuning_window_size: 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 5.788644349398552
# lambda: 0.1, mse : 5.788644349398552
# lambda: 1, mse : 5.788644349398552
# lambda: 10, mse : 5.788644349398552
# lambda: 15, mse : 5.788644349398552
# lambda: 25, mse : 5.788644349398552
#
# Finished Tuning on lambda
# best model mse : 5.788644349398552
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.1254803536802148
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.04155567329600561
# Finished Tuning [1/4] in 2162.83 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3e0c8ae10>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [2/4] at example 24998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 1.109536066636207
# lambda: 0.1, mse : 1.1094817822044882
# lambda: 1, mse : 1.109007669461376
# lambda: 10, mse : 1.105578314440054
# lambda: 15, mse : 1.1045785175986966
# lambda: 25, mse : 1.104153665961793
#
# Finished Tuning on lambda
# best model mse : 1.104153665961793
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.0881563918609038
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.01593617082549848
# Finished Tuning [2/4] in 2013.42 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x35573b290>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 24998
# after i+=tuning_window_size, i is : 27998
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [3/4] at example 49996...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.21802159256822143
# lambda: 0.1, mse : 0.2180931984763863
# lambda: 1, mse : 0.21874208404191173
# lambda: 10, mse : 0.22564500763237016
# lambda: 15, mse : 0.2297779376039927
# lambda: 25, mse : 0.23859654450200757
#
# Finished Tuning on lambda
# best model mse : 0.21802159256822143
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.19922740791561935
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.06507550035482408
# Finished Tuning [3/4] in 2128.13 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 50, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x392344dd0>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 49996
# after i+=tuning_window_size, i is : 52996
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [4/4] at example 74994...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.728725104999135
# lambda: 0.1, mse : 0.7290199226999493
# lambda: 1, mse : 0.7316776606999427
# lambda: 10, mse : 0.7586420286437952
# lambda: 15, mse : 0.7738759100613791
# lambda: 25, mse : 0.8047344936001488
#
# Finished Tuning on lambda
# best model mse : 0.728725104999135
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.17542148761068563
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.02285981011016287
# Finished Tuning [4/4] in 1937.46 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3395322d0>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 74994
# after i+=tuning_window_size, i is : 77994
# Size of ht predictions: 87992
# Size of kde predictions: 87992
# Size of actual labels: 87992
#
# Final Mean Squared Errors:
# hat MSE:      0.1475
# hat+HS MSE:   0.1612
# hat+KDE MSE:     0.0476

# %%
from Code.incremental_kde import NYTaxi_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

NYTaxi_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/nyc_taxi_kaggle/train.csv", model_name='hat', n_rows=20000, no_lambda=False, parameters=parameters)
# Out:
# Processing dataset NYC TAXI
# samples : 19997, number of features : 10
# y shape : (19997,)
# initializing a hat
# model name is hat
# models to tune : 1081
# tuning_window_size: 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 42.379482888027894
# lambda: 0.1, mse : 42.379482888027894
# lambda: 1, mse : 42.379482888027894
# lambda: 10, mse : 42.379482888027894
# lambda: 15, mse : 42.379482888027894
# lambda: 25, mse : 42.379482888027894
#
# Finished Tuning on lambda
# best model mse : 42.379482888027894
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.3673294840003195
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.27422247601797606
# Finished Tuning [1/4] in 7120.94 seconds.
#
# Best parameters after tuning: {'lambda_selected': 25, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x4900bfa10>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [2/4] at example 4999...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.34042299490631106
# lambda: 0.1, mse : 0.34042299490631106
# lambda: 1, mse : 0.34042299490631106
# lambda: 10, mse : 0.34042299490631106
# lambda: 15, mse : 0.34042299490631106
# lambda: 25, mse : 0.34042299490631106
#
# Finished Tuning on lambda
# best model mse : 0.34042299490631106
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2829650897770159
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.23107953423994532
# Finished Tuning [2/4] in 7469.50 seconds.
#
# Best parameters after tuning: {'lambda_selected': 15, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x5c3763110>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 7498
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [3/4] at example 9998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.2366621446426694
# lambda: 0.1, mse : 0.23666335935799027
# lambda: 1, mse : 0.2366743230762992
# lambda: 10, mse : 0.23678703029297363
# lambda: 15, mse : 0.2368520263584727
# lambda: 25, mse : 0.23698701533969577
#
# Finished Tuning on lambda
# best model mse : 0.2366621446426694
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2172457667890351
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.2172457667890351
# Finished Tuning [3/4] in 7902.05 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 9998
# after i+=tuning_window_size, i is : 12497
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [4/4] at example 14997...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 6
# lambda: 0, mse : 0.2257574915246255
# lambda: 0.1, mse : 0.22575778971632338
# lambda: 1, mse : 0.22576052601899207
# lambda: 10, mse : 0.22579294852345597
# lambda: 15, mse : 0.22581477668149136
# lambda: 25, mse : 0.22586611724368424
#
# Finished Tuning on lambda
# best model mse : 0.2257574915246255
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 1081
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.20869610896140509
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# tuning on model : 600
# tuning on model : 650
# tuning on model : 700
# tuning on model : 750
# tuning on model : 800
# tuning on model : 850
# tuning on model : 900
# tuning on model : 950
# tuning on model : 1000
# tuning on model : 1050
# best model mse : 0.20869610896140509
# Finished Tuning [4/4] in 10187.86 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 14997
# after i+=tuning_window_size, i is : 17496
# Size of ht predictions: 10001
# Size of kde predictions: 10001
# Size of actual labels: 10001
#
# Final Mean Squared Errors:
# hat MSE:      0.2693
# hat+HS MSE:   0.2693
# hat+KDE MSE:     0.2426

# %%
from Code.incremental_kde import NYTaxi_experiment
#Second experiment with KDE+HS
parameters = {
       #'lambda_list' : [0, 5, 15, 20, 50],
       'lambda_list' : [0, 0.1, 1, 10, 15, 25],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }

NYTaxi_experiment(path="/Users/pantia-marinaalchirch/Documents/OU/Research/Streams/data/nyc_taxi_kaggle/train.csv", model_name='hat', n_rows=20000, no_lambda=True, parameters=parameters)
# Out:
# Processing dataset NYC TAXI
# samples : 19997, number of features : 10
# y shape : (19997,)
# initializing a hat
# no lambda tuning in KDE
# model name is hat
# models to tune : 181
# tuning_window_size: 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [1/4] at example 0...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 42.379482888027894
# lambda: 0.1, mse : 42.379482888027894
# lambda: 1, mse : 42.379482888027894
# lambda: 10, mse : 42.379482888027894
# lambda: 15, mse : 42.379482888027894
# lambda: 25, mse : 42.379482888027894
#
# Finished Tuning on lambda
# best model mse : 42.379482888027894
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.3673294840003195
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.27483811060105484
# Finished Tuning [1/4] in 1180.55 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x874217910>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2499
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [2/4] at example 4999...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.34042299490631106
# lambda: 0.1, mse : 0.34042299490631106
# lambda: 1, mse : 0.34042299490631106
# lambda: 10, mse : 0.34042299490631106
# lambda: 15, mse : 0.34042299490631106
# lambda: 25, mse : 0.34042299490631106
#
# Finished Tuning on lambda
# best model mse : 0.34042299490631106
# Best lambda after tuning: 25
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2829650897770159
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.23119492788895413
# Finished Tuning [2/4] in 1225.04 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0.0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x889227790>, 'kde_type': 'binned', 'range_of_bin': 0.2}
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 7498
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [3/4] at example 9998...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.2366621446426694
# lambda: 0.1, mse : 0.23666335935799027
# lambda: 1, mse : 0.2366743230762992
# lambda: 10, mse : 0.23678703029297363
# lambda: 15, mse : 0.2368520263584727
# lambda: 25, mse : 0.23698701533969577
#
# Finished Tuning on lambda
# best model mse : 0.2366621446426694
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.2172457667890351
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.2172457667890351
# Finished Tuning [3/4] in 1370.24 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 9998
# after i+=tuning_window_size, i is : 12497
# tuning_start_indices: [0, 4999, 9998, 14997]
# Tuning [4/4] at example 14997...
# Tuning on mse...
# Tuning on lambda
#  models to tune : 1
# lambda: 0, mse : 0.2257574915246255
# lambda: 0.1, mse : 0.22575778971632338
# lambda: 1, mse : 0.22576052601899207
# lambda: 10, mse : 0.22579294852345597
# lambda: 15, mse : 0.22581477668149136
# lambda: 25, mse : 0.22586611724368424
#
# Finished Tuning on lambda
# best model mse : 0.2257574915246255
# Best lambda after tuning: 0
#
# Tune on KDE...
#  models to tune : 181
# len(y_true) : 2499
# len(model.predictions) : 2499
# fallback model mse : 0.20869610896140509
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# best model mse : 0.20869610896140509
# Finished Tuning [4/4] in 1289.52 seconds.
#
# Best parameters after tuning: {'lambda_selected': None, 'h': None, 'window_size': None, 'kernel': None, 'kde_type': None, 'range_of_bin': None}
#
# before i+=tuning_window_size, i is : 14997
# after i+=tuning_window_size, i is : 17496
# Size of ht predictions: 10001
# Size of kde predictions: 10001
# Size of actual labels: 10001
#
# Final Mean Squared Errors:
# hat MSE:      0.2693
# hat+HS MSE:   0.2693
# hat+KDE MSE:     0.2431
