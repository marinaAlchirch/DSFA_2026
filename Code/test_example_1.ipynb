# %%
from Code.example_1 import run_example

run_example()
# Out:
# Label/Query 1
# 1.4513657299587222
# Label/Query 2
# 6.175685873364919e-12
# Label/Query 3
# 0.4837885766559953
# Label/Query 4
# 0.9675771533073587
# Label/Query 5
# 3.0878429366824596e-12
# KDE with bandwidth 0.1 : [np.float64(1.4513657299587222), np.float64(6.175685873364919e-12), np.float64(0.4837885766559953), np.float64(0.9675771533073587), np.float64(3.0878429366824596e-12)]
# KDE Distribution with bandwidth 0.1 : [np.float64(0.49999999999760647), np.float64(2.127542956905492e-12), np.float64(0.1666666666669326), np.float64(0.33333333333226955), np.float64(1.063771478452746e-12)]
# Label/Query 1
# 0.2916878324961694
# Label/Query 2
# 0.13704817807540637
# Label/Query 3
# 0.16808304705851426
# Label/Query 4
# 0.22709826224642238
# Label/Query 5
# 0.0685241017829251
# KDE with bandwidth 0.5 : [np.float64(0.2916878324961694), np.float64(0.13704817807540637), np.float64(0.16808304705851426), np.float64(0.22709826224642238), np.float64(0.0685241017829251)]
# ...
