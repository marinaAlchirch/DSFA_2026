# %%
from Code.incremental_kde import california_experiment

parameters = {
       'lambda_list': [0, 10, 50],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }
# parameters = {
#         'lambda_list': [0],
#         #'lambda_list': [0, 50],
#         'h_list': [100, 500, 1000],
#         'window_size_list': [50, 100, 200]
#     }

california_experiment(parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# tuning_window_size: 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.34757168115116643
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.28122048154668566
# Finished Tuning [1/4] in 2135.57 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x342aec590>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [2/4] at example 5160...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.45193092513301536
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.3297699047050937
# Finished Tuning [2/4] in 2214.89 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x361f75a90>, 'kde_type': 'binned', 'range_of_bin': 2}
#
# before i+=tuning_window_size, i is : 5160
# after i+=tuning_window_size, i is : 7740
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [3/4] at example 10320...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.4191385394309153
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.3889496861242882
# Finished Tuning [3/4] in 2239.20 seconds.
#
# Best parameters after tuning: {'lambda_selected': 10, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3ece56d50>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 10320
# after i+=tuning_window_size, i is : 12900
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [4/4] at example 15480...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 3.5719588109886806
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.4505902990747304
# Finished Tuning [4/4] in 2328.47 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x4338a9e10>, 'kde_type': 'binned', 'range_of_bin': 2}
#
# before i+=tuning_window_size, i is : 15480
# after i+=tuning_window_size, i is : 18060
# Size of ht predictions: 10320
# Size of kde predictions: 10320
# Size of actual labels: 10320
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# iSoup MSE:      0.6760
# iSoup+HS MSE:   5.2152
# HT with KDE MSE:     0.5849

# %%
#HAT experiment

# %%
from Code.incremental_kde import california_experiment

parameters = {
       'lambda_list': [0, 10, 50],
       #'lambda_list': [0, 50],
       'h_list': [10, 50, 100],
       'window_size_list': [50, 100, 200]
    }
# parameters = {
#         'lambda_list': [0],
#         #'lambda_list': [0, 50],
#         'h_list': [100, 500, 1000],
#         'window_size_list': [50, 100, 200]
#     }

california_experiment(parameters=parameters)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# tuning_window_size: 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.3287001164375852
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.27460136072707075
# Finished Tuning [1/4] in 2278.26 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x3252f3e90>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [2/4] at example 5160...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.39179139841993593
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.27065617940280856
# Finished Tuning [2/4] in 2334.71 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x13a940310>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 5160
# after i+=tuning_window_size, i is : 7740
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [3/4] at example 10320...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 0.494534124522143
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.32295547549402903
# Finished Tuning [3/4] in 2315.32 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 200, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x13e85ea90>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 10320
# after i+=tuning_window_size, i is : 12900
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [4/4] at example 15480...
# Tuning on mse...
#  models to tune : 325
# len(y_true) : 2580
# len(model.predictions) : 2580
# fallback model mse : 8.070830814462305
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# best model mse : 0.46541081300522225
# Finished Tuning [4/4] in 2354.44 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x32c27f210>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 15480
# after i+=tuning_window_size, i is : 18060
# Size of ht predictions: 10320
# Size of kde predictions: 10320
# Size of actual labels: 10320
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# iSoup MSE:      0.5017
# iSoup+HS MSE:   0.4988
# HT with KDE MSE:     0.4926

# %%
import copy
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import MinMaxScaler
from Code.california_housing_dataset_cleaning import clean_data
import pandas as pd
import numpy as np


# Load data
data = fetch_california_housing(as_frame=True)
features_of_interest = ["AveRooms", "AveBedrms", "AveOccup", "Population"]
data = clean_data(data, features_of_interest)
X, y = data.data, data.target  # small batch for quick test

# Preprocessing
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)


if isinstance(y, pd.Series):
    y = y.values
y = np.array(y)

training_labels = []
tuning_window_size = int(len(X) / (2 * 4))  # for example, use 50% of each tuning segment
tuning_start_indices = [int(i * len(X) / 4) for i in range(4)]
i = 0
while i < len(X):
    if i in tuning_start_indices:
        i += tuning_window_size
    else:

        if str(type(X)) == '<class \'pandas.core.frame.DataFrame\'>':
            instance_features = X.iloc[i:i + 1].values
        elif str(type(X)) == '<class \'numpy.ndarray\'>':
            instance_features = X[i].reshape(1, -1)
        else:
            raise TypeError('X type must either be pandas.core.frame.DataFrame or numpy.ndarray')

        actual_value = y[i]
        training_labels.append(actual_value)

        i += 1

np.savetxt('/Users/pantia-marinaalchirch/PycharmProjects/ht_library_my_version/results/california/y_true.txt', training_labels)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data

# %%
from Code.incremental_kde import NYTaxi_experiment


parameters = {
        'lambda_list': [0, 50],
    #'lambda_list':[0],
        'h_list': [1, 5, 50, 100],
        'window_size_list': [50, 100, 200]
    }
NYTaxi_experiment(parameters=parameters, tuning_times=4)
# Out:
# samples : 9998, number of features : 10
# y shape : (9998,)
# Processing dataset NYC TAXI
# tuning_window_size: 1249
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 289
# len(y_true) : 1249
# len(model.predictions) : 1249
# fallback model mse : 0.39032019997665995
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# best model mse : 0.3175932684835978
# Finished Tuning [1/4] in 690.01 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 5, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x309169710>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 1249
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [2/4] at example 2499...
# Tuning on mse...
#  models to tune : 289
# len(y_true) : 1249
# len(model.predictions) : 1249
# fallback model mse : 0.3268238293097316
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# best model mse : 0.2084114513134466
# Finished Tuning [2/4] in 714.59 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 5, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x330c00590>, 'kde_type': 'binned', 'range_of_bin': 2}
#
# before i+=tuning_window_size, i is : 2499
# after i+=tuning_window_size, i is : 3748
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [3/4] at example 4999...
# Tuning on mse...
#  models to tune : 289
# len(y_true) : 1249
# len(model.predictions) : 1249
# fallback model mse : 0.33485207248191184
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# best model mse : 0.2297919748952971
# Finished Tuning [3/4] in 731.55 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 5, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x35a5efd10>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 6248
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [4/4] at example 7498...
# Tuning on mse...
#  models to tune : 289
# len(y_true) : 1249
# len(model.predictions) : 1249
# fallback model mse : 0.23401798771505897
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# best model mse : 0.21105824784897292
# Finished Tuning [4/4] in 742.59 seconds.
#
# Best parameters after tuning: {'lambda_selected': 50, 'h': 5, 'window_size': 50, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x3819faa50>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 7498
# after i+=tuning_window_size, i is : 8747
# Size of ht predictions: 5002
# Size of kde predictions: 5002
# Size of actual labels: 5002
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# HAT MSE:      0.3243
# HAT+HS MSE:   0.3244
# HAT with KDE MSE:     0.2485

# %% [markdown]
# #Electric power consumption dataset : Hebrail, G. & Berard, A. (2006). Individual Household Electric Power Consumption [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C58K54.

# %%
import os, ssl, certifi, urllib.request
os.environ["SSL_CERT_FILE"] = certifi.where()
ssl_context = ssl.create_default_context(cafile=certifi.where())
urllib.request.install_opener(
    urllib.request.build_opener(urllib.request.HTTPSHandler(context=ssl_context))
)

# %%
from Code.incremental_kde import electric_power_comsumption_experiment

parameters = {
        'lambda_list': [0, 1, 5],
    #'lambda_list':[0],
        'h_list': [1, 5, 10, 100],
    #'h_list': [1],
        'window_size_list': [100, 200, 500, 1000]
    #'window_size_list': [100, 200]
    }

electric_power_comsumption_experiment(parameters=parameters, tuning_times=4)
# Out:
# (99992, 8) (99992,)
# tuning_window_size: 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 577
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.1254803536802148
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# best model mse : 0.036817542117846935
# Finished Tuning [1/4] in 5689.76 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 500, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x14d459390>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 3000
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [2/4] at example 24998...
# Tuning on mse...
#  models to tune : 577
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.0881563918609038
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# best model mse : 0.01579419897075074
# Finished Tuning [2/4] in 5274.18 seconds.
#
# Best parameters after tuning: {'lambda_selected': 1, 'h': 10, 'window_size': 100, 'kernel': <Code.kernels.CustomEpanechnikovKernel object at 0x34a03b250>, 'kde_type': 'binned', 'range_of_bin': 1}
#
# before i+=tuning_window_size, i is : 24998
# after i+=tuning_window_size, i is : 27998
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [3/4] at example 49996...
# Tuning on mse...
#  models to tune : 577
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.19922740791561935
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# best model mse : 0.0638781773316259
# Finished Tuning [3/4] in 5618.98 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 1, 'window_size': 200, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x34b094a90>, 'kde_type': 'labeled', 'range_of_bin': 0}
#
# before i+=tuning_window_size, i is : 49996
# after i+=tuning_window_size, i is : 52996
# tuning_start_indices: [0, 24998, 49996, 74994]
# Tuning [4/4] at example 74994...
# Tuning on mse...
#  models to tune : 577
# len(y_true) : 3000
# len(model.predictions) : 3000
# fallback model mse : 0.17542148761068563
# tuning on model : 50
# tuning on model : 100
# tuning on model : 150
# tuning on model : 200
# tuning on model : 250
# tuning on model : 300
# tuning on model : 350
# tuning on model : 400
# tuning on model : 450
# tuning on model : 500
# tuning on model : 550
# best model mse : 0.02304662037061507
# Finished Tuning [4/4] in 4948.84 seconds.
#
# Best parameters after tuning: {'lambda_selected': 0, 'h': 10, 'window_size': 500, 'kernel': <Code.kernels.CustomGaussianKernel object at 0x349eeff10>, 'kde_type': 'binned', 'range_of_bin': 2}
#
# before i+=tuning_window_size, i is : 74994
# after i+=tuning_window_size, i is : 77994
# Size of ht predictions: 87992
# Size of kde predictions: 87992
# Size of actual labels: 87992
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# HAT MSE:      0.1475
# HAT+HS MSE:   0.1476
# HT with KDE MSE:     0.0811

# %% [markdown]
#  # Tune and train only on lambda

# %%
from Code.incremental_kde import california_experiment_hs

lambda_list = [1, 5, 10, 15, 20] # for lambda <= 20 we have better HT+HS results than HT, with lambda==20 ==lambda_list best results

california_experiment_hs(lambda_list=lambda_list, tuning_times=4)
# Out:
# Number of illogical examples:  5
# Illogical examples : [3364, 13034, 16669, 19006, 15360]
# Per feature the illogical examples are :
# HouseAge:  0
# AveRooms:  0
# AveBeds:  0
# Population:  1
# AveOccup:  4
# Dropping those examples from data
# tuning_window_size: 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 5
# lambda: 1, mse : 3.7644853251949217
# lambda: 5, mse : 3.7644853251949217
# lambda: 10, mse : 3.7644853251949217
# lambda: 15, mse : 3.7644853251949217
# lambda: 20, mse : 3.7644853251949217
# best model mse : 3.7644853251949217
# Finished Tuning [1/4] in 0.01 seconds.
#
# Best lambda after tuning: 20
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 2580
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [2/4] at example 5160...
# Tuning on mse...
#  models to tune : 5
# lambda: 1, mse : 1.5951840534634218
# lambda: 5, mse : 1.5590887944725367
# lambda: 10, mse : 1.5160400596911046
# lambda: 15, mse : 1.4751575342996475
# lambda: 20, mse : 1.436308623009081
# best model mse : 1.436308623009081
# Finished Tuning [2/4] in 0.14 seconds.
#
# Best lambda after tuning: 20
#
# before i+=tuning_window_size, i is : 5160
# after i+=tuning_window_size, i is : 7740
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [3/4] at example 10320...
# Tuning on mse...
#  models to tune : 5
# lambda: 1, mse : 0.45377969517083105
# lambda: 5, mse : 0.4485244447499455
# lambda: 10, mse : 0.4424883943236993
# lambda: 15, mse : 0.43700207416071946
# lambda: 20, mse : 0.43202413998975675
# best model mse : 0.43202413998975675
# Finished Tuning [3/4] in 0.15 seconds.
#
# Best lambda after tuning: 20
#
# before i+=tuning_window_size, i is : 10320
# after i+=tuning_window_size, i is : 12900
# tuning_start_indices: [0, 5160, 10320, 15480]
# Tuning [4/4] at example 15480...
# Tuning on mse...
#  models to tune : 5
# lambda: 1, mse : 0.3108995282285065
# lambda: 5, mse : 0.31115291612018303
# lambda: 10, mse : 0.3117747144254671
# lambda: 15, mse : 0.3127051621876204
# lambda: 20, mse : 0.3139150964022029
# best model mse : 0.3108995282285065
# Finished Tuning [4/4] in 0.14 seconds.
#
# Best lambda after tuning: 1
#
# before i+=tuning_window_size, i is : 15480
# after i+=tuning_window_size, i is : 18060
# Size of ht predictions: 10320
# Size of actual labels: 10320
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# HT MSE:      0.4928
# HT+HS MSE:   0.4898

# %%
 # Tune and train only on lambda
from Code.incremental_kde import NYTaxi_experiment_hs

lambda_list = [0.1, 1, 2, 3, 5, 7, 10, 15, 20, 21, 25, 27, 28]  # for lambda <= 28 we have same HT+HS results with HT

NYTaxi_experiment_hs(lambda_list=lambda_list, tuning_times=4)
# Out:
# samples : 9998, number of features : 10
# y shape : (9998,)
# Processing dataset NYC TAXI
# tuning_window_size: 1249
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [1/4] at example 0...
# Tuning on mse...
#  models to tune : 13
# lambda: 0.1, mse : 42.70135791536213
# lambda: 1, mse : 42.70135791536213
# lambda: 2, mse : 42.70135791536213
# lambda: 3, mse : 42.70135791536213
# lambda: 5, mse : 42.70135791536213
# lambda: 7, mse : 42.70135791536213
# lambda: 10, mse : 42.70135791536213
# lambda: 15, mse : 42.70135791536213
# lambda: 20, mse : 42.70135791536213
# lambda: 21, mse : 42.70135791536213
# lambda: 25, mse : 42.70135791536213
# lambda: 27, mse : 42.70135791536213
# lambda: 28, mse : 42.70135791536213
# best model mse : 42.70135791536213
# Finished Tuning [1/4] in 0.28 seconds.
#
# Best lambda after tuning: 28
#
# before i+=tuning_window_size, i is : 0
# after i+=tuning_window_size, i is : 1249
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [2/4] at example 2499...
# Tuning on mse...
#  models to tune : 13
# lambda: 0.1, mse : 0.34259145167273414
# lambda: 1, mse : 0.34259145167273414
# lambda: 2, mse : 0.34259145167273414
# lambda: 3, mse : 0.34259145167273414
# lambda: 5, mse : 0.34259145167273414
# lambda: 7, mse : 0.34259145167273414
# lambda: 10, mse : 0.34259145167273414
# lambda: 15, mse : 0.34259145167273414
# lambda: 20, mse : 0.34259145167273414
# lambda: 21, mse : 0.34259145167273414
# lambda: 25, mse : 0.34259145167273414
# lambda: 27, mse : 0.34259145167273414
# lambda: 28, mse : 0.34259145167273414
# best model mse : 0.34259145167273414
# Finished Tuning [2/4] in 0.58 seconds.
#
# Best lambda after tuning: 28
#
# before i+=tuning_window_size, i is : 2499
# after i+=tuning_window_size, i is : 3748
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [3/4] at example 4999...
# Tuning on mse...
#  models to tune : 13
# lambda: 0.1, mse : 0.3363524763241433
# lambda: 1, mse : 0.3363524763241433
# lambda: 2, mse : 0.3363524763241433
# lambda: 3, mse : 0.3363524763241433
# lambda: 5, mse : 0.3363524763241433
# lambda: 7, mse : 0.3363524763241433
# lambda: 10, mse : 0.3363524763241433
# lambda: 15, mse : 0.3363524763241433
# lambda: 20, mse : 0.3363524763241433
# lambda: 21, mse : 0.3363524763241433
# lambda: 25, mse : 0.3363524763241433
# lambda: 27, mse : 0.3363524763241433
# lambda: 28, mse : 0.3363524763241433
# best model mse : 0.3363524763241433
# Finished Tuning [3/4] in 0.46 seconds.
#
# Best lambda after tuning: 28
#
# before i+=tuning_window_size, i is : 4999
# after i+=tuning_window_size, i is : 6248
# tuning_start_indices: [0, 2499, 4999, 7498]
# Tuning [4/4] at example 7498...
# Tuning on mse...
#  models to tune : 13
# lambda: 0.1, mse : 0.2727620387943043
# lambda: 1, mse : 0.2727401403535777
# lambda: 2, mse : 0.27271588066787145
# lambda: 3, mse : 0.27269169656545533
# lambda: 5, mse : 0.27264355462812245
# lambda: 7, mse : 0.2725957135788868
# lambda: 10, mse : 0.27252451407237094
# lambda: 15, mse : 0.2724073391232664
# lambda: 20, mse : 0.27229201495443156
# lambda: 21, mse : 0.2722691709184116
# lambda: 25, mse : 0.2721785268648065
# lambda: 27, mse : 0.2721336424617576
# lambda: 28, mse : 0.27211130925991783
# best model mse : 0.27211130925991783
# Finished Tuning [4/4] in 0.54 seconds.
#
# Best lambda after tuning: 28
#
# before i+=tuning_window_size, i is : 7498
# after i+=tuning_window_size, i is : 8747
# Size of ht predictions: 5002
# Size of actual labels: 5002
# Test passed: All prediction lists are of correct length!
#
# Final Mean Squared Errors:
# HT MSE:      0.3243
# HT+HS MSE:   0.3243
